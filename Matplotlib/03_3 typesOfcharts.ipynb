# %%
#plt.bar(x, height, color='color name', width= value, label='label name')

import matplotlib.pyplot as plt

product = ['A','B','C','D']
sales= [1000, 1500, 800, 1700]

plt.bar(product, sales, color="purple", label= "2025 Sales")
plt.xlabel("Products")
plt.ylabel("Sales amount")
plt.title("Product sale comparison")
plt.legend(loc="upper right")
plt.ylim(0,2000)
plt.show()

# %%
#plt.pie(values, labels=label_list, colors=color_list, autopct='%1.1f%%' )

import matplotlib.pyplot as plt
Regions = ['North', 'South', 'East', 'West']
revenue = [1700, 2100, 1000, 1200]

plt.pie(revenue, labels=Regions, autopct='%1.1f%%', colors=['gold','lightblue','lightgreen','lightpink'])
plt.title("Revenue Contribution By Region")
plt.show()

# %%
#plt.hist(data, bins=number_of_bins, color='Colorname', edgecolor='black')

import matplotlib.pyplot as plt

scores = [45, 67, 24, 52, 75, 82, 92, 64, 8, 53, 74, 68, 89, 84, 93, 56, 35, 78,32,53,74,85,37,86,58,97,66,97,4]
plt.hist(scores, bins=5, color='gold', edgecolor='black')
plt.xlabel('Score Range')
plt.ylabel('Number of Students')
plt.title('Score distribution of students')
plt.show()
